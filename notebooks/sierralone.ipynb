# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# LOAD THE DATASET

# %%
print("Overview of the dataset: the first 5 rows")
df = pd.read_csv("C:/Users/Student/Documents/kaim documents/data/data/sierraleone-bumbuna.csv")
df.head()
# Out:
# Overview of the dataset: the first 5 rows
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002         0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002         0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
print("Overview of the dataset: the last 5 rows")
df.tail()
# Out:
# Overview of the dataset: the last 5 rows
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb     RH   WS  WSgust  \
# 525595  2022-10-29 23:56 -1.6 -0.1 -2.9   0.0   0.0  24.0  100.0  0.0     0.0
# 525596  2022-10-29 23:57 -1.7 -0.1 -3.0   0.0   0.0  24.0  100.0  0.0     0.0
# 525597  2022-10-29 23:58 -1.7 -0.1 -3.1   0.0   0.0  24.0  100.0  0.0     0.0
# 525598  2022-10-29 23:59 -1.7 -0.2 -3.3   0.0   0.0  23.9  100.0  0.0     0.0
# 525599  2022-10-30 00:00 -1.7 -0.1 -3.4   0.0   0.0  23.9  100.0  0.0     0.0
#
#         WSstdev   WD  WDstdev    BP  Cleaning  Precipitation  TModA  TModB  \
# 525595      0.0  0.0      0.0   999         0            0.0   24.2   24.5
# 525596      0.0  0.0      0.0   999         0            0.0   24.2   24.5
# 525597      0.0  0.0      0.0  1000         0            0.0   24.1   24.4
# 525598      0.0  0.0      0.0  1000         0            0.0   24.1   24.4
# 525599      0.0  0.0      0.0  1000         0            0.0   24.1   24.4
#
#         Comments
# 525595       NaN
# 525596       NaN
# 525597       NaN
# 525598       NaN
# 525599       NaN

# %%
print("Overview of numeric columns")
df.describe()
# Out:
# Overview of numeric columns
#                  GHI            DNI            DHI           ModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      201.957515     116.376337     113.720571     206.643095
# std       298.495150     218.652659     158.946032     300.896893
# min       -19.500000      -7.800000     -17.900000       0.000000
# 25%        -2.800000      -0.300000      -3.800000       0.000000
# 50%         0.300000      -0.100000      -0.100000       3.600000
# 75%       362.400000     107.000000     224.700000     359.500000
# max      1499.000000     946.000000     892.000000    1507.000000
#
#                 ModB           Tamb             RH             WS  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      198.114691      26.319394      79.448857       1.146113
# std       288.889073       4.398605      20.520775       1.239248
# min         0.000000      12.300000       9.900000       0.000000
# 25%         0.000000      23.100000      68.700000       0.000000
# 50%         3.400000      25.300000      85.400000       0.800000
# 75%       345.400000      29.400000      96.700000       2.000000
# max      1473.000000      39.900000     100.000000      19.200000
#
#               WSgust        WSstdev             WD        WDstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean        1.691606       0.363823     133.044668       7.172220
# std         1.617053       0.295000     114.284792       7.535093
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.600000       0.400000     161.500000       6.200000
# 75%         2.600000       0.600000     234.100000      12.000000
# max        23.900000       4.100000     360.000000      98.400000
#
#                   BP       Cleaning  Precipitation          TModA  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      999.876469       0.000967       0.004806      32.504263
# std         2.104419       0.031074       0.047556      12.434899
# min       993.000000       0.000000       0.000000      10.700000
# 25%       999.000000       0.000000       0.000000      23.500000
# 50%      1000.000000       0.000000       0.000000      26.600000
# 75%      1001.000000       0.000000       0.000000      40.900000
# max      1006.000000       1.000000       2.400000      72.800000
#
#                TModB  Comments
# count  525600.000000       0.0
# mean       32.593091       NaN
# std        12.009161       NaN
# min        11.100000       NaN
# 25%        23.800000       NaN
# 50%        26.900000       NaN
# 75%        41.300000       NaN
# max        70.400000       NaN

# %%
print("Overview of categorical columns")
df.describe(include=['object'])
# Out:
# Overview of categorical columns
#                Timestamp
# count             525600
# unique            525600
# top     2022-10-29 23:44
# freq                   1

# %%
print("Overview of all columns")
df.describe(include='all')
# Out:
# Overview of all columns
#                Timestamp            GHI            DNI            DHI  \
# count             525600  525600.000000  525600.000000  525600.000000
# unique            525600            NaN            NaN            NaN
# top     2022-10-29 23:44            NaN            NaN            NaN
# freq                   1            NaN            NaN            NaN
# mean                 NaN     201.957515     116.376337     113.720571
# std                  NaN     298.495150     218.652659     158.946032
# min                  NaN     -19.500000      -7.800000     -17.900000
# 25%                  NaN      -2.800000      -0.300000      -3.800000
# 50%                  NaN       0.300000      -0.100000      -0.100000
# 75%                  NaN     362.400000     107.000000     224.700000
# max                  NaN    1499.000000     946.000000     892.000000
#
#                  ModA           ModB           Tamb             RH  \
# count   525600.000000  525600.000000  525600.000000  525600.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean       206.643095     198.114691      26.319394      79.448857
# std        300.896893     288.889073       4.398605      20.520775
# min          0.000000       0.000000      12.300000       9.900000
# 25%          0.000000       0.000000      23.100000      68.700000
# 50%          3.600000       3.400000      25.300000      85.400000
# 75%        359.500000     345.400000      29.400000      96.700000
# max       1507.000000    1473.000000      39.900000     100.000000
#
#                    WS         WSgust        WSstdev             WD  \
# count   525600.000000  525600.000000  525600.000000  525600.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         1.146113       1.691606       0.363823     133.044668
# std          1.239248       1.617053       0.295000     114.284792
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       0.000000       0.000000
# 50%          0.800000       1.600000       0.400000     161.500000
# 75%          2.000000       2.600000       0.600000     234.100000
# max         19.200000      23.900000       4.100000     360.000000
#
#               WDstdev             BP       Cleaning  Precipitation  \
# count   525600.000000  525600.000000  525600.000000  525600.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         7.172220     999.876469       0.000967       0.004806
# std          7.535093       2.104419       0.031074       0.047556
# min          0.000000     993.000000       0.000000       0.000000
# 25%          0.000000     999.000000       0.000000       0.000000
# 50%          6.200000    1000.000000       0.000000       0.000000
# 75%         12.000000    1001.000000       0.000000       0.000000
# max         98.400000    1006.000000       1.000000       2.400000
#
#                 TModA          TModB  Comments
# count   525600.000000  525600.000000       0.0
# unique            NaN            NaN       NaN
# top               NaN            NaN       NaN
# freq              NaN            NaN       NaN
# mean        32.504263      32.593091       NaN
# std         12.434899      12.009161       NaN
# min         10.700000      11.100000       NaN
# 25%         23.500000      23.800000       NaN
# 50%         26.600000      26.900000       NaN
# 75%         40.900000      41.300000       NaN
# max         72.800000      70.400000       NaN

# %%
print("overview of the dataset shape")
df.info()
# Out:
# overview of the dataset shape
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  object
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
#  16  TModA          525600 non-null  float64
#  17  TModB          525600 non-null  float64
#  18  Comments       0 non-null       float64
# dtypes: float64(16), int64(2), object(1)
# memory usage: 76.2+ MB

# %% [markdown]
# ### Step 1: Convert Timestamp to datetime
# We need to parse the 'Timestamp' column correctly to perform time-series operations.

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')

# %%
### Step 2: check datatype of comment and convert it to appropriate datatype
print(df['Comments'].unique())
# Out:
# [nan]

# %%
# Check if 'Comments' is textual and convert to string if needed
df['Comments'] = df['Comments'].astype('string')

# %%
print(df.dtypes)
# Out:
# Timestamp        datetime64[ns]
# GHI                     float64
# DNI                     float64
# DHI                     float64
# ModA                    float64
# ModB                    float64
# Tamb                    float64
# RH                      float64
# WS                      float64
# WSgust                  float64
# WSstdev                 float64
# WD                      float64
# WDstdev                 float64
# BP                        int64
# Cleaning                  int64
# Precipitation           float64
# TModA                   float64
# TModB                   float64
# Comments         string[python]
# dtype: object

# %%
print("checking for missing values")
df.isna().sum()
# Out:
# checking for missing values
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %%
# Drop the Comments column since it's entirely missing
df_cleaned = df.drop(columns=['Comments'])

# %%
# here to check for duplicates if they exist
duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# OUTLIER DETECTION

# %%
# identify numeric columns
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
print(f"Numeric columns:{numeric_cols}")
# Out:
# Numeric columns:['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'Tamb', 'RH', 'WS', 'WSgust', 'WSstdev', 'WD', 'WDstdev', 'BP', 'Cleaning', 'Precipitation', 'TModA', 'TModB']

# %% [markdown]
# # ✅ Winsorization (Outlier Handling)
#
# **Purpose:**
# Reduce the influence of extreme outlier values by capping them at the 1st and 99th percentiles.
#
# **Steps:**
# 1. Select all numeric columns in the dataset.
# 2. For each column:
#    - Calculate the 1st and 99th percentiles.
#    - Replace values below the 1st percentile with the 1st percentile.
#    - Replace values above the 99th percentile with the 99th percentile.
#
# **Advantages:**
# - Keeps the dataset size the same.
# - Reduces the influence of extreme values.
# - More robust than deletion and less distortion than mean imputation.

# %%
print("Before Winsorization:")
print(df[['DNI']].describe())
# Out:
# Before Winsorization:
#                  DNI
# count  525600.000000
# mean      116.376337
# std       218.652659
# min        -7.800000
# 25%        -0.300000
# 50%        -0.100000
# 75%       107.000000
# max       946.000000

# %%
# Step 1: Select numeric columns only (excluding Timestamp if present)
numeric_cols = df.select_dtypes(include=[np.number]).columns

# Step 2: Apply Winsorization to each numeric column
for col in numeric_cols:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df[col] = np.clip(df[col], lower, upper)

# %%
print("\nAfter Winsorization:")
print(df[['DNI']].describe())
# Out:
# After Winsorization:
#                  DNI
# count  525600.000000
# mean      115.959626
# std       217.275236
# min        -0.800000
# 25%        -0.300000
# 50%        -0.100000
# 75%       107.000000
# max       795.300000

# %%
df.describe()
# Out:
#                            Timestamp            GHI            DNI  \
# count                         525600  525600.000000  525600.000000
# mean   2022-04-30 12:00:30.000000768     201.105142     115.959626
# min              2021-10-30 00:01:00     -12.800000      -0.800000
# 25%              2022-01-29 06:00:45      -2.800000      -0.300000
# 50%              2022-04-30 12:00:30       0.300000      -0.100000
# 75%              2022-07-30 18:00:15     362.400000     107.000000
# max              2022-10-30 00:00:00    1025.000000     795.300000
# std                              NaN     295.889330     217.275236
#
#                  DHI           ModA           ModB           Tamb  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean      113.215773     205.855071     197.314406      26.321907
# min       -12.900000       0.000000       0.000000      17.300000
# 25%        -3.800000       0.000000       0.000000      23.100000
# 50%        -0.100000       3.600000       3.400000      25.300000
# 75%       224.700000     359.500000     345.400000      29.400000
# max       556.900000    1011.200000     983.000000      36.500000
# std       157.352689     298.590486     286.503811       4.346477
#
#                   RH             WS         WSgust        WSstdev  \
# count  525600.000000  525600.000000  525600.000000  525600.000000
# mean       79.490713       1.135078       1.676672       0.361488
# min        18.500000       0.000000       0.000000       0.000000
# 25%        68.700000       0.000000       0.000000       0.000000
# 50%        85.400000       0.800000       1.600000       0.400000
# 75%        96.700000       2.000000       2.600000       0.600000
# max       100.000000       4.600000       6.200000       1.100000
# std        20.390624       1.194974       1.555169       0.286451
#
#                   WD        WDstdev             BP  Cleaning  Precipitation  \
# count  525600.000000  525600.000000  525600.000000  525600.0  525600.000000
# mean      132.967873       7.095984     999.882376       0.0       0.002296
# min         0.000000       0.000000     995.000000       0.0       0.000000
# 25%         0.000000       0.000000     999.000000       0.0       0.000000
# 50%       161.500000       6.200000    1000.000000       0.0       0.000000
# 75%       234.100000      12.000000    1001.000000       0.0       0.000000
# max       344.400000      29.600000    1004.000000       0.0       0.100000
# std       114.139187       7.211791       2.068895       0.0       0.014978
#
#                TModA          TModB
# count  525600.000000  525600.000000
# mean       32.498229      32.591097
# min        16.100000      16.500000
# 25%        23.500000      23.800000
# 50%        26.600000      26.900000
# 75%        40.900000      41.300000
# max        63.400000      60.700000
# std        12.365028      11.950824

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525600 entries, 0 to 525599
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Timestamp      525600 non-null  datetime64[ns]
#  1   GHI            525600 non-null  float64
#  2   DNI            525600 non-null  float64
#  3   DHI            525600 non-null  float64
#  4   ModA           525600 non-null  float64
#  5   ModB           525600 non-null  float64
#  6   Tamb           525600 non-null  float64
#  7   RH             525600 non-null  float64
#  8   WS             525600 non-null  float64
#  9   WSgust         525600 non-null  float64
#  10  WSstdev        525600 non-null  float64
#  11  WD             525600 non-null  float64
#  12  WDstdev        525600 non-null  float64
#  13  BP             525600 non-null  int64
#  14  Cleaning       525600 non-null  int64
#  15  Precipitation  525600 non-null  float64
#  16  TModA          525600 non-null  float64
#  17  TModB          525600 non-null  float64
#  18  Comments       0 non-null       string
# dtypes: datetime64[ns](1), float64(15), int64(2), string(1)
# memory usage: 76.2 MB
# Timestamp             0
# GHI                   0
# DNI                   0
# DHI                   0
# ModA                  0
# ModB                  0
# Tamb                  0
# RH                    0
# WS                    0
# WSgust                0
# WSstdev               0
# WD                    0
# WDstdev               0
# BP                    0
# Cleaning              0
# Precipitation         0
# TModA                 0
# TModB                 0
# Comments         525600
# dtype: int64

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
df.hist(figsize=(15, 12), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let us perform univariate, bivariate, and correlation analysis for those relevant column
# GHI,DNI,DHI,ModA,ModB,TModA,TModB,WS

# %%
for col in ['GHI', 'DNI', 'DHI']:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
sample_df = df.sample(5000, random_state=42)
for col in ['ModA', 'ModB', 'WS']:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=sample_df[col])
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)
    plt.show()

# %% [markdown]
# BIVARIATE SCATTER PLOT

# %%
plt.figure(figsize=(10, 8))
corr = df[['GHI', 'DNI', 'DHI', 'ModA', 'ModB','TModA','TModB','WS']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Key Variables')
plt.show()

# %%
sample_df = df.sample(5000, random_state=42)
sns.pairplot(sample_df[['GHI', 'DNI', 'DHI']])
plt.suptitle('Pairplot of Irradiance Variables', y=1.02)
plt.show()
